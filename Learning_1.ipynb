# %%
a = 1
b = 1
c = -6
x = 2

# %%
y = a*  x ** 2 + b * x +c
print(y)
# Out:
# 0

# %%
x = -2
y = a* x ** (2) + b * x +c
print (y)
# Out:
# -4

# %%
x = 0
y = a* x ** (2) + b * x +c
print (y)
# Out:
# -6

# %%
print("1/3 gives", 1/3)
# Out:
# 1/3 gives 0.3333333333333333

# %%
print ("a:",a)
# Out:
# a: 1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,4,2])

# %%
import numpt as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-18020a175f7c> in <module>()
# ----> 1 import numpt as np
#
# ModuleNotFoundError: No module named 'numpt'

# %%
import numpy as np

x = np.linspace(-4, 4, 5)
print(x)
# Out:
# [-4. -2.  0.  2.  4.]

# %%
a = 1
b = 1 
c = -6
x = np.linspace(-4, 4, 100)
y = a * x ** 2 + b * x +c
plt.plot(x, y)

# %%
plt.plot([1,2,3], [2,4,3], linewidth = 6);

# %%
x = np.linspace(-3,3,100)
y = (x+2) * (x-1) * (x-2)
plt.plot(x,y,"r--")
plt.plot([-2,1,2],[0,0,0],"bo",markersize=10)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("First Python Figure of Mark Bakker")
# Out:
# Text(0.5,1,'First Python Figure of Mark Bakker')

# %%
holland = np.loadtxt("holland_temperature.dat")
newyork = np.loadtext("newyork_temperature.dat")
beijing = np.loadtxt("beijing_temperature.dat")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-29-ca08ce59530d> in <module>()
# ----> 1 holland = np.loadtxt("holland_temperature.dat")
#       2 newyork = np.loadtext("newyork_temperature.dat")
#       3 beijing = np.loadtxt("beijing_temperature.dat")
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     915             fname = str(fname)
#     916         if _is_string_like(fname):
# --> 917             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     918             fencoding = getattr(fh, 'encoding', 'latin1')
#     919             fh = iter(fh)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     258
#     259     ds = DataSource(destpath)
# --> 260     return ds.open(path, mode, encoding=encoding, newline=newline)
#     261
#     262
#
# ~\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     614                                       encoding=encoding, newline=newline)
#     615         else:
# --> 616             raise IOError("%s not found." % path)
#     617
#     618
#
# OSError: holland_temperature.dat not found.

# %%
plt.plot([1,2,3],[4,5,2],"xkcd:baby puke green");
