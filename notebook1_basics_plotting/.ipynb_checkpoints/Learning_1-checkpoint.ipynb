# %%
a = 1
b = 1
c = -6
x = 2

# %%
y = a*  x ** 2 + b * x +c
print(y)
# Out:
# 0

# %%
x = -2
y = a* x ** (2) + b * x +c
print (y)
# Out:
# -4

# %%
x = 0
y = a* x ** (2) + b * x +c
print (y)
# Out:
# -6

# %%
print("1/3 gives", 1/3)
# Out:
# 1/3 gives 0.3333333333333333

# %%
print ("a:",a)
# Out:
# a: 1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,4,2])

# %%
import numpy as np

# %%
import numpy as np

x = np.linspace(-4, 4, 5)
print(x)
# Out:
# [-4. -2.  0.  2.  4.]

# %%
a = 1
b = 1 
c = -6
x = np.linspace(-4, 4, 100)
y = a * x ** 2 + b * x +c
plt.plot(x, y)

# %%
plt.plot([1,2,3], [2,4,3], linewidth = 6);

# %%
x = np.linspace(-3,3,100)
y = (x+2) * (x-1) * (x-2)
plt.plot(x,y,"r--")
plt.plot([-2,1,2],[0,0,0],"bo",markersize=10)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("First nice Python Figure of Mac Sanders")
# Out:
# Text(0.5,1,'First nice Python Figure of Mac Sanders')

# %%
Holland=np.loadtxt("holland_temperature.dat")

# %%
Beijing = np.loadtxt("beijing_temperature.dat")

# %%
New_York = np.loadtxt("newyork_temperature.dat")

# %%
Holland_Seawater = np.loadtxt("holland_seawater.dat")

# %%
plt.plot(np.linspace(1,12,12),Holland)
plt.xlabel("Number of the Month")
plt.ylabel("Mean Monthly Temperature (Celcius)")
# Out:
# Text(0,0.5,'Mean Monthly Temperature (Celcius)')

# %%
plt.plot(np.linspace(1,12,12),New_York)
plt.xticks(np.linspace(1,12,12))
# Out:
# ([<matplotlib.axis.XTick at 0x18619ade828>,
#   <matplotlib.axis.XTick at 0x18619ade1d0>,
#   <matplotlib.axis.XTick at 0x18619ade0b8>,
#   <matplotlib.axis.XTick at 0x18619af8e48>,
#   <matplotlib.axis.XTick at 0x18619aff390>,
#   <matplotlib.axis.XTick at 0x18619aff898>,
#   <matplotlib.axis.XTick at 0x18619affda0>,
#   <matplotlib.axis.XTick at 0x18619b082e8>,
#   <matplotlib.axis.XTick at 0x18619b087f0>,
#   <matplotlib.axis.XTick at 0x18619b08cf8>,
#   <matplotlib.axis.XTick at 0x18619b0f240>,
#   <matplotlib.axis.XTick at 0x18619b0f748>],
#  <a list of 12 Text xticklabel objects>)

# %%
plt.plot(np.linspace(1,12,12),Beijing)
plt.legend(["Holland"],loc="best")

# %%
plt.plot(np.linspace(1,12,12),Holland)
plt.plot(np.linspace(1,12,12),New_York)
plt.plot(np.linspace(1,12,12),Beijing)
plt.xlabel("Number of the Month")
plt.ylabel("Mean Monthly Temperature (Celcius)")
plt.xticks(np.linspace(1,12,12))
plt.legend(["Holland","New York","Beijing"], loc = "best");

# %%
Water = np.loadtxt("holland_seawater.dat")
Air = np.loadtxt("holland_temperature.dat")

# %%
plt.subplot?

# %%
plt.subplot(111)
#I do not truly know why I have done the "211" withing the subplot command 
#even after reading the help given by the prompt above playing with it
#it seems if plt.subplot(abc) a controls y axis b x axis and c I have no idea
plt.plot(Air,"b",label="Air Temperature");
plt.plot(Water,"g",label="Water Temperature");
plt.legend(loc="best");
plt.ylabel("Temperature (Celcius)");
plt.xlim(0,11)
plt.xticks([])
plt.subplot(212)
plt.plot(Air-Water,"ko");
plt.xticks(np.linspace(0,11,12),["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]);
plt.xlim(0,11)
plt.ylabel("Air-Sea Temperature (Celsius)")

#Tried doing this with help from answer guide for some reason my first graph
#disappears not sure why
# Out:
# Text(0,0.5,'Air-Sea Temperature (Celsius)')

# %%
air = np.loadtxt('holland_temperature.dat') 
sea = np.loadtxt('holland_seawater.dat')
plt.subplot(211)
plt.plot(air, 'b', label='air temp')
plt.plot(sea, 'r', label='sea temp')
plt.legend(loc='best')
plt.ylabel('temp (Celcius)')
plt.xlim(0, 11)
plt.xticks([])
plt.subplot(212)
plt.plot(air-sea, 'ko')
plt.xticks(np.linspace(0, 11, 12),
           ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'])
plt.xlim(0, 11)
plt.ylabel('air - sea temp (Celcius)');

# %%
plt.plot([1,2,3],[4,5,2],"xkcd:poop brown")

# %%
plt.pie?

# %%
medals = [46,38,29,24,13,11,11,8,8,7,107]

# %%
medals
# Out:
# [46, 38, 29, 24, 13, 11, 11, 8, 8, 7, 107]

# %%
Countries = ["USA","CHN","GBR","RUS","KOR","GER","FRA","ITA","HUN","AUS","OTHER"]

# %%
Countries
# Out:
# ['USA', 'CHN', 'GBR', 'RUS', 'KOR', 'GER', 'FRA', 'ITA', 'HUN', 'AUS', 'OTHER']

# %%
plt.pie(medals, labels = Countries);
plt.axis("equal");

# %%
Air
# Out:
# array([ 3.1,  3.3,  6.2,  9.2, 13.1, 15.6, 17.9, 17.5, 14.5, 10.7,  6.7,
#         3.7])

# %%
Water
# Out:
# array([ 5.5,  4.5,  5.7,  7.3, 11.7, 14.8, 17.5, 20. , 19. , 17.2, 13. ,
#         8.8])

# %%
plt.fill_between?

# %%
plt.fill_between(range(1,13),air,color="b",alpha=.3);
plt.fill_between(range(1,13),sea,color="r",alpha = .3);
plt.xticks(np.linspace(0,11,12),["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]);
plt.xlim(1,12);
plt.ylim(0,20);
plt.xlabel("Month");
plt.ylabel("Temperature (Celsius)");
